# %%
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.types import Integer, String, Float, Date, DateTime, Boolean


def connect_to_db():
    try:
        engine = create_engine('postgresql+psycopg2://adminkbbkbu:adminkbbkbu_io@localhost:5432/kb_group',
                                connect_args={'options': '-c search_path=bronze_layer'})
        connection = engine.connect()
        print("Connection to the database was successful.")
        return connection

    except Exception as e:  
        print(f"An error occurred: {e}")

# %%
class DatabaseConfig:
    def connect_to_db(self):
        """"""
        try:
            engine = create_engine('postgresql+psycopg2://adminkbbkbu:adminkbbkbu_io@localhost:5432/kb_group',
                                    connect_args={'options': '-c search_path=bronze_layer'})
            connection = engine.connect()
            print("Connection to the database was successful.")
            return connection

        except Exception as e:  
            print(f"An error occurred: {e}")
    
    def mapping_fd_inline(self):
        """"""
        dtype_fd_inline = {
            "model": String(15),
            "part_no": String(12),
            "part_name": String(50),
            "ttd_kasie": String(3),
            "ttd_operator": String(3),
            "nik_operator": String(15),
            "tahun": Integer,
            "bulan": Integer,
            "tanggal": Integer,
            "shift": Integer,
            "welding_check_points": Integer,
            "keropos": Integer,
            "kurang": Integer,
            "bolong": Integer,
            "undercut": Integer,
            "spatter": Integer,
            "tidak_tepat": Integer
        }

        return dtype_fd_inline
    
    def mapping_fd_noninline(self):
        """"""
        dtype_fd_noninline = {
            "model": String(15),
            "part_no": String(12),
            "part_name": String(50),
            "ttd_kasie": String(3),
            "ttd_operator": String(3),
            "nik_operator": String(15),
            "tahun": Integer,
            "bulan": Integer,
            "tanggal": Integer,
            "shift": Integer,
            "checked": Integer,
            "ok": Integer,
            "repair": Integer,
            "scrap": Integer,
            "folding_Keras": Integer,
            "karat": Integer,
            "deformasi": Integer,
            "cat_coating": Integer,
            "tidak_masuk_gonogo": Integer,
            "step_loss": Integer,
            "step_loncat": Integer,
            "step_lebih": Integer,
            "step_kurang": Integer,
            "salah_pasang": Integer,
            "goresan": Integer,
            "noisy": Integer,
            "tidak_lengkap": Integer,
            "catatan": String(50),
            "title": String(25),
            "file_name_dataset": String(50),
            "start_processing": String(50),
            "end_processing": String(50),
            "time_processing_all": String(20),
            "time_processing_page": String(20),
            "login_id": String(30),
            "table_1": String(50),
            "table_2": String(50), 
            "table_3": String(50),
            "table_4": String(50),
            "table_5": String(50),
            "table_6": String(50),
        }

        return dtype_fd_noninline
    
    def mapping_fpd(self):
        """"""
        dtype_fpd = {
            "model": String(15),
            "part_no": String(12),
            "part_name": String(50),
            "part_group": String(6),
            "nik_nipm": String(15),
            "tahun": Integer,
            "bulan": Integer,
            "tanggal": Integer,
            "shift": Integer,
            "total_repair": Integer,
            "total_top": Integer,
            "total_middle": Integer,
            "total_bottom": Integer,
            "title": String(25),
            "file_name_dataset": String(50),
            "start_processing": String(50),
            "end_processing": String(50),
            "time_processing_all": String(20),
            "time_processing_page": String(20),
            "login_id": String(30),
            "table_1": String(50),
            "table_2": String(50)
        }

        return dtype_fpd
        
    def mapping_users_activity(self):
        """"""
        dtype_users_activity = {
            "username": String(10),
            "name": String(25),
            "nik_nipm": String(15),
            "role": String(15),
            "location": String(6),
            "login_id": String(30)
        }

        return dtype_users_activity

# %%
df_trial = pd.DataFrame({
                "Model": ["4L45W", "4L45W", "4L45W"],
                "Part_No": ["M017T120", "M017T120", "M017T120"],
                "Part_Name": ["FRM_ASM_3RD_RH", "FRM_ASM_3RD_LH", "FRM_ASM_3RD_RH"],
                "Ttd_Kasie": ["E", "A", "C"],
                "Ttd_Operator": ["A", "B", "D"],
                "Nik_Operator": ["112", "111", "113"],
                "Tahun": ["2025", "2025", "2025"],
                "Bulan": ["9", "9", "9"],
                "Tanggal": ["12", "12", "12"],
                "Shift": ["1", "1", "1"],
                "Welding_Check_Points": ["1", "2", "3"],
                "Keropos": ["0", "1", "0"],
                "Kurang": ["1", "0", "0"],
                "Bolong": ["0", "0", "1"],
                "Undercut": ["0", "1", "0"],
                "Spatter": ["0", "0", "1"],
                "Tidak_Tepat": ["0", "1", "0"]
            })
df_trial
# Out:
#    Model   Part_No       Part_Name Ttd_Kasie Ttd_Operator Nik_Operator Tahun  \
# 0  4L45W  M017T120  FRM_ASM_3RD_RH         E            A          112  2025
# 1  4L45W  M017T120  FRM_ASM_3RD_LH         A            B          111  2025
# 2  4L45W  M017T120  FRM_ASM_3RD_RH         C            D          113  2025
#
#   Bulan Tanggal Shift Welding_Check_Points Keropos Kurang Bolong Undercut  \
# 0     9      12     1                    1       0      1      0        0
# 1     9      12     1                    2       1      0      0        1
# 2     9      12     1                    3       0      0      1        0
#
#   Spatter Tidak_Tepat
# 0       0           0
# 1       0           1
# 2       1           0

# %%
df_trial.columns = df_trial.columns.str.lower()

# %%
df_trial.to_sql(
            'fd_inline',
            con=connect_to_db(),
            if_exists='append',
            index=False,
            dtype=DatabaseConfig().mapping_fd_inline())
# Out:
# Connection to the database was successful.
# 3

# %%
df_check = pd.read_sql_query(text("SELECT * FROM bronze_layer.fd_inline"), connect_to_db())
df_check
# Out:
# Connection to the database was successful.
#    model   part_no       part_name ttd_kasie ttd_operator nik_operator  tahun  \
# 0  4L45W  M017T120  FRM_ASM_3RD_RH         E            A          112   2025
# 1  4L45W  M017T120  FRM_ASM_3RD_LH         A            B          111   2025
# 2  4L45W  M017T120  FRM_ASM_3RD_RH         C            D          113   2025
# 3  4L45W  M017T120  FRM_ASM_3RD_RH         E            A          112   2025
# 4  4L45W  M017T120  FRM_ASM_3RD_LH         A            B          111   2025
# 5  4L45W  M017T120  FRM_ASM_3RD_RH         C            D          113   2025
#
#    bulan  tanggal  shift  welding_check_points  keropos  kurang  bolong  \
# 0      9       12      1                     1        0       1       0
# 1      9       12      1                     2        1       0       0
# 2      9       12      1                     3        0       0       1
# 3      9       12      1                     1        0       1       0
# ...

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 3 non-null      object
#  1   part_no               3 non-null      object
#  2   part_name             3 non-null      object
#  3   ttd_kasie             3 non-null      object
#  4   ttd_operator          3 non-null      object
#  5   nik_operator          3 non-null      object
#  6   tahun                 3 non-null      int64
#  7   bulan                 3 non-null      int64
#  8   tanggal               3 non-null      int64
#  9   shift                 3 non-null      int64
#  10  welding_check_points  3 non-null      int64
#  11  keropos               3 non-null      int64
#  12  kurang                3 non-null      int64
#  13  bolong                3 non-null      int64
#  14  undercut              3 non-null      int64
# ...

# %%
con = connect_to_db()
# Out:
# Connection to the database was successful.

# %%
df = pd.read_sql_query(text("SELECT * FROM bronze_layer.fd_noninline"), con=con)
df1 = pd.read_sql_query(text("SELECT * FROM bronze_layer.fpd"), con=con)

# %%
df
# Out:
#      halaman model   part_no      part_name ttd_kasie ttd_operator nik_nipm  \
# 0  Halaman 1  5J45  M081T010  FRM_ASM_FB_RH         H            E     1225
# 1  Halaman 1  5J45  M081T010  FRM_ASM_FB_RH         H            E     1225
# 2  Halaman 1  5J45  M081T010  FRM_ASM_FB_RH         H            E     1225
# 3  Halaman 1  5H45  M031T010  FRM_ASM_FB_RH         H            E     1225
# 4  Halaman 1  5J45  M081T010  FRM_ASM_FB_RH         H            E     1225
# 5  Halaman 1  5J45  M081T010  FRM_ASM_FB_RH         H            E     1225
# 6  Halaman 1  5J45  M081T010  FRM_ASM_FB_RH         H            E     1225
#
#   tahun bulan tanggal  ...              end_processing time_processing_all  \
# 0  2025    10      22  ...  2025-11-17 13:59:44.028826               12.52
# 1  2025    10      22  ...  2025-11-17 14:04:37.503783               18.71
# 2  2025    10      22  ...  2025-11-17 14:08:58.138601               12.68
# ...

# %%
df1
# Out:
#      halaman  model   part_no        part_name part_group nik_nipm tahun  \
# 0  Halaman 1  4L45W  M017S110  FRM_ASM_3RDC_RH       3RDC     1206  2025
# 1  Halaman 1  4L45W  M017S110  FRM_ASM_3RDC_RH       3RDC     1206  2025
#
#   bulan tanggal shift  ... total_bottom               title  \
# 0     2       2     2  ...           21  First Pass Defects
# 1     1       1     2  ...           21  First Pass Defects
#
#                                    file_name_dataset  \
# 0  FRM-QC-026_rev3_2025-11-17_First_Pass_Defects_...
# 1  FRM-QC-026_rev3_2025-11-17_First_Pass_Defects_...
#
#              start_processing              end_processing time_processing_all  \
# 0   2025-11-17 15:14:11.43427  2025-11-17 15:15:20.626477               19.52
# 1  2025-11-17 15:21:51.424534  2025-11-17 15:22:51.220698               31.08
#
#   time_processing_page                    login_id  \
# 0   19.517340898513794  LGN_2025-11-17_15-13_KBU 2
# 1   31.084185123443604  LGN_2025-11-17_15-21_KBU 2
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Name": [None, None, None, None],
    "Age": [28, None, 30, None],
    "City": ["Jakarta", None, "Bandung", None]
})

print(df)
# Out:
#    Name   Age     City
# 0  None  28.0  Jakarta
# 1  None   NaN     None
# 2  None  30.0  Bandung
# 3  None   NaN     None

# %%
if False in df['Name'].isnull().to_list():
    print("Hai")

# %%
['keropos', 'kurang', 'bolong', 'undercut', 'spatter', 'tidak_tepat']
[]

# %% [markdown]
# ### **Create Connection With Database PostgreSQL**

# %%
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.types import Integer, String, Float, Date, DateTime, Boolean

# %%
def connect_to_db():
    
    """"""
    try:
        engine = create_engine('postgresql+psycopg2://airflow:airflow@10.10.0.154:5433/kb_group',
                                connect_args={'options': '-c search_path=bronze_layer'})
        connection = engine.connect()
        print("Connection to the database was successful.")
        return connection

    except Exception as e:  
        print(f"An error occurred: {e}")

# %%
conn = connect_to_db()
# Out:
# Connection to the database was successful.

# %%
def get_database(start_date: str, end_date: str, db_name, col_name):
    try : 
        if isinstance(col_name, list):
            columns = ", ".join(col_name)
        else : 
            columns = col_name

        template_query = text(f"""
                              SELECT 
                                {columns},
                                MAKE_DATE(tahun::INT, bulan::INT, tanggal::INT) AS production_date 
                              FROM 
                                bronze_layer.{db_name}
                              WHERE
                                MAKE_DATE(tahun::INT, bulan::INT, tanggal::INT) BETWEEN :start AND :end;
                              """)
        df = pd.read_sql_query(sql=template_query, con=connect_to_db(), params={'start' :start_date, 'end' :end_date})

        return df
    
    except Exception as e : 
        print(f"Error : {e}")

# %%
col_name = ['model', 'part_no', 'part_name', 'shift', 'tahun', 'bulan', 'tanggal', 'checked', 'ok', 'repair', 'scrap']
df_noninline = get_database(start_date='2025-10-20', end_date='2025-10-23', db_name='fd_noninline', col_name=col_name)
df_noninline
# Out:
# Connection to the database was successful.
#     model     part_no             part_name shift tahun bulan tanggal checked  \
# 0    5J45    M081T010         FRM_ASM_FB_RH     1  2025    10      22      64
# 1    5H45    M031T010         FRM_ASM_FB_RH     1  2025    10      22     120
# 2    5H45    M031T010         FRM_ASM_FB_RH     2  2025    10      22     120
# 3    5J45    M081T010         FRM_ASM_FB_RH     2  2025    10      22      64
# 4    5H45    M032T010         FRM_ASM_FB_LH     2  2025    10      22     160
# ..    ...         ...                   ...   ...   ...   ...     ...     ...
# 72  4L45W  M015T210-A   FRM_ASM_2NDB_RH_MIX     1  2025    10      20      86
# 73  4L45W  M016T210-A    FRM_ASM_2NDB_LH_UN     1  2025    10      20     129
# 74  4L45W  M016T210-A    FRM_ASM_2NDB_LH_UN     2  2025    10      20     215
# 75  4L45W    M012T010  FRM_ASM_FB_LH_NON_UN     1  2025    10      20     129
# ...

# %%
col_name = ['model', 'part_no', 'part_name', 'shift', 'total_repair', 'tahun', 'bulan', 'tanggal']
df_fpd = get_database(start_date='2025-10-20', end_date='2025-10-23', db_name='fpd', col_name=col_name)
df_fpd
# Out:
# Connection to the database was successful.
#             model   part_no              part_name shift total_repair  \
# 0           4L45W  M017T410  FRM_ASM_3RDB_RH(22MY)     2           25
# 1           4L45W  M017S120        FRM_ASM_3RDC_LH     2            0
# 2           4L45W  M017S110        FRM_ASM_3RDC_RH     2           21
# 3    4L45W (26MY)  M066S030    FRM_ASM_2NDC_LH_MIX     2           61
# 4    4L45W (26MY)  M065S030    FRM_ASM_2NDC_RH_MIX     2           40
# ..            ...       ...                    ...   ...          ...
# 148          5H45  M031T010          FRM_ASM_FB_RH     2           17
# 149          5J45  M081T010          FRM_ASM_FB_RH     2            9
# 150         4L45W  M016S020     FRM_ASM_2NDC_LH_UN     1           39
# 151          5H45  M032T010          FRM_ASM_FB_LH     2           32
# 152         4L45W  M017T410  FRM_ASM_3RDB_RH(22MY)     2           30
#
#     production_date
# 0        2025-10-20
# 1        2025-10-20
# ...

# %%
df = pd.read_sql_query(sql=("SELECT * FROM bronze_layer.fpd"), con=connect_to_db())
df
# Out:
# Connection to the database was successful.
#         halaman         model   part_no              part_name part_group  \
# 0     Halaman 1         4L45W  M017T410  FRM_ASM_3RDB_RH(22MY)       3RDB
# 1     Halaman 1         4L45W  M017S120        FRM_ASM_3RDC_LH       3RDC
# 2     Halaman 2         4L45W  M017S110        FRM_ASM_3RDC_RH       3RDC
# 3     Halaman 3  4L45W (26MY)  M066S030    FRM_ASM_2NDC_LH_MIX       2NDC
# 4     Halaman 5  4L45W (26MY)  M065S030    FRM_ASM_2NDC_RH_MIX       2NDC
# ..          ...           ...       ...                    ...        ...
# 197  Halaman 60          5H45  M031T010          FRM_ASM_FB_RH         FR
# 198  Halaman 61          5J45  M082T010          FRM_ASM_FB_LH         FR
# 199  Halaman 62          5J45  M082T010          FRM_ASM_FB_LH         FR
# 200  Halaman 63          5J45  M081T010          FRM_ASM_FB_RH         FR
# 201  Halaman 64          5J45  M081T010          FRM_ASM_FB_RH         FR
#
# ...

# %% [markdown]
# ### **Transformation Data Local To Server**

# %%
def db_local():
    """"""
    try:
        engine = create_engine('postgresql+psycopg2://adminkbbkbu:adminkbbkbu_io@localhost:5432/kb_group',
                                connect_args={'options': '-c search_path=bronze_layer'})
        connection = engine.connect()
        print("Connection to the database was successful.")
        return connection

    except Exception as e:  
        print(f"An error occurred: {e}")

def db_sever():
    """"""
    try:
        engine = create_engine('postgresql+psycopg2://airflow:airflow@10.10.0.154:5433/kb_group',
                                connect_args={'options': '-c search_path=bronze_layer'})
        connection = engine.connect()
        print("Connection to the database was successful.")
        return connection

    except Exception as e:  
        print(f"An error occurred: {e}")

# %%
con_server = db_sever()
con_local = db_local()
# Out:
# Connection to the database was successful.
# Connection to the database was successful.

# %%
query_sql = text("""SELECT * FROM bronze_layer.fd_noninline""") 
query_sql_2 = text("""SELECT * FROM bronze_layer.fpd""")
query_sql_3 = text("""SELECT * FROM bronze_layer.fd_inline""")
query_sql_4 = text("""SELECT * FROM bronze_layer.users_activity""")

# %%
df_local_fd_noninline = pd.read_sql_query(query_sql, con=con_local)
df_local_fd_inline = pd.read_sql_query(query_sql_3, con=con_local)
df_local_fpd = pd.read_sql_query(query_sql_2, con=con_local)
df_local_users = pd.read_sql_query(query_sql_4, con=con_local)
df_local_fd_noninline
# Out:
#         halaman  model     part_no             part_name ttd_kasie  \
# 0     Halaman 1   5J45    M081T010         FRM_ASM_FB_RH         H
# 1     Halaman 2   5H45    M031T010         FRM_ASM_FB_RH         H
# 2     Halaman 3   5H45    M031T010         FRM_ASM_FB_RH         H
# 3     Halaman 4   5J45    M081T010         FRM_ASM_FB_RH         H
# 4     Halaman 5   5H45    M032T010         FRM_ASM_FB_LH         H
# ..          ...    ...         ...                   ...       ...
# 109  Halaman 33  4L45W  M016T120-A    FRM_ASM_2NDB_LH_UN         E
# 110  Halaman 34  4L45W  M016T210-A   FRM_ASM_2NDB_LH_MIX         €
# 111  Halaman 35  4L45W  M016T210-A    FRM_ASM_2NDB_LH_UN         5
# 112  Halaman 36  4L45W    M011T010  FRM_ASM_FB_RH_NON_UN         E
# 113  Halaman 37  4L45W    M012T010  FRM_ASM_FB_LH_NON_UN         E
#
#     ttd_operator nik_nipm tahun bulan tanggal  ...  \
# 0              E     1225  2025    10      22  ...
# 1              E     1225  2025    10      22  ...
# ...

# %%
df_local_fpd
# Out:
#         halaman         model   part_no              part_name part_group  \
# 0     Halaman 1         4L45W  M017T410  FRM_ASM_3RDB_RH(22MY)       3RDB
# 1     Halaman 1         4L45W  M017S120        FRM_ASM_3RDC_LH       3RDC
# 2     Halaman 2         4L45W  M017S110        FRM_ASM_3RDC_RH       3RDC
# 3     Halaman 3  4L45W (26MY)  M066S030    FRM_ASM_2NDC_LH_MIX       2NDC
# 4     Halaman 5  4L45W (26MY)  M065S030    FRM_ASM_2NDC_RH_MIX       2NDC
# ..          ...           ...       ...                    ...        ...
# 197  Halaman 60          5H45  M031T010          FRM_ASM_FB_RH         FR
# 198  Halaman 61          5J45  M082T010          FRM_ASM_FB_LH         FR
# 199  Halaman 62          5J45  M082T010          FRM_ASM_FB_LH         FR
# 200  Halaman 63          5J45  M081T010          FRM_ASM_FB_RH         FR
# 201  Halaman 64          5J45  M081T010          FRM_ASM_FB_RH         FR
#
#     nik_nipm tahun bulan tanggal shift  ... total_bottom               title  \
# ...

# %%
df_local_fpd.to_sql(name='fpd', con=con_server, if_exists='append', index=False)
print(f"Sucess")
# Out:
# Sucess

# %%
df_local_fd_noninline
# Out:
#         halaman  model     part_no             part_name ttd_kasie  \
# 0     Halaman 1   5J45    M081T010         FRM_ASM_FB_RH         H
# 1     Halaman 2   5H45    M031T010         FRM_ASM_FB_RH         H
# 2     Halaman 3   5H45    M031T010         FRM_ASM_FB_RH         H
# 3     Halaman 4   5J45    M081T010         FRM_ASM_FB_RH         H
# 4     Halaman 5   5H45    M032T010         FRM_ASM_FB_LH         H
# ..          ...    ...         ...                   ...       ...
# 109  Halaman 33  4L45W  M016T120-A    FRM_ASM_2NDB_LH_UN         E
# 110  Halaman 34  4L45W  M016T210-A   FRM_ASM_2NDB_LH_MIX         €
# 111  Halaman 35  4L45W  M016T210-A    FRM_ASM_2NDB_LH_UN         5
# 112  Halaman 36  4L45W    M011T010  FRM_ASM_FB_RH_NON_UN         E
# 113  Halaman 37  4L45W    M012T010  FRM_ASM_FB_LH_NON_UN         E
#
#     ttd_operator nik_nipm tahun bulan tanggal  ...  \
# 0              E     1225  2025    10      22  ...
# 1              E     1225  2025    10      22  ...
# ...

# %%
df_local_fd_noninline.to_sql(name='fd_noninline', con=con_server, if_exists='append', index=False)
# Out:
# 114

# %%
df_local_fd_inline.to_sql(name='fd_inline', con=con_server, if_exists='append', index=False)
# Out:
# 719

# %%
df_local_users.to_sql(name='users_activity', con=con_server, if_exists='append', index=False)
# Out:
# 11
